# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# Define the directory path
directory_path = r"C:\Users\Jack\Desktop\foodRecipeAndInteractions"

for dirname, _, filenames in os.walk(directory_path):
    for filename in filenames:
        full_path = os.path.join(dirname, filename)
        print(full_path)

# %%
# Option 1: Using double backslashes
file_path = "C:\\Users\\Jack\\Desktop\\foodRecipeAndInteractions\\RAW_recipes.csv"

# Option 2: Using raw string
# file_path = r"C:\Users\Jack\Desktop\foodRecipeAndInteractions\RAW_recipes.csv"

a = pd.read_csv(file_path)
print(a.head(2))
