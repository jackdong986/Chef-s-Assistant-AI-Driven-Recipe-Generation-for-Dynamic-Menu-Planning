# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# Define the directory path
directory_path = r"C:\Users\Jack\Desktop\ResMenuFYP\foodRecipeAndInteractions"

for dirname, _, filenames in os.walk(directory_path):
    for filename in filenames:
        full_path = os.path.join(dirname, filename)
        print(full_path)
# Out:
# C:\Users\Jack\Desktop\ResMenuFYP\foodRecipeAndInteractions\ingr_map.pkl
# C:\Users\Jack\Desktop\ResMenuFYP\foodRecipeAndInteractions\interactions_test.csv
# C:\Users\Jack\Desktop\ResMenuFYP\foodRecipeAndInteractions\interactions_train.csv
# C:\Users\Jack\Desktop\ResMenuFYP\foodRecipeAndInteractions\interactions_validation.csv
# C:\Users\Jack\Desktop\ResMenuFYP\foodRecipeAndInteractions\PP_recipes.csv
# C:\Users\Jack\Desktop\ResMenuFYP\foodRecipeAndInteractions\PP_users.csv
# C:\Users\Jack\Desktop\ResMenuFYP\foodRecipeAndInteractions\RAW_interactions.csv
# C:\Users\Jack\Desktop\ResMenuFYP\foodRecipeAndInteractions\RAW_recipes.csv

# %%
# Option 1: Using double backslashes
file_path = "C:\\Users\\Jack\\Desktop\\ResMenuFYP\\foodRecipeAndInteractions\\RAW_interactions.csv"

# Option 2: Using raw string
# file_path = r"C:\Users\Jack\Desktop\ResMenuFYP\foodRecipeAndInteractions\RAW_interactions.csv"

a = pd.read_csv(file_path)
print(a.head(2))
# Out:
#    user_id  recipe_id        date  rating  \
# 0    38094      40893  2003-02-17       4
# 1  1293707      40893  2011-12-21       5
#
#                                               review
# 0  Great with a salad. Cooked on top of stove for...
# 1  So simple, so delicious! Great for chilly fall...
